# %% [markdown]
# # To-Do Lists
#
# - [X] 2D Nonlinear Solid Dynamics
# - [ ] 2D Nonlinear Solid Transients
# - [X] 3D Nonlinear Solid Dynamics
# - [ ] 3D Nonlinear Solid Transients
# - [ ] 3D Nonlinear Solid Dynamics with Animated Result Visualization
# - [X] 3D CFD: Schäfer-Turek Benchmark
# - [X] 2D FSI: Schäfer-Turek Benchmark
# - [X] 2D FSI: Multi-layered Sandwich
# - [ ] 3D FSI: Multi-layered Cylindrical-hole in Block
# - [ ] 3D FSI: Aorta in Abdomen
# - [ ] 3D FSI: Aneuryms Aorta in Abdomen
